# %%
# Import an audio file
from pydub import AudioSegment
wav_file = AudioSegment.from_file(file="output.wav") # format="wav" infered
type(wav_file)
# Out:
# pydub.audio_segment.AudioSegment

# %%
# Play an audio file
from pydub.playback import play
wav_file = AudioSegment.from_file(file="output.wav")
# Play audio file
play(wav_file)

# %% [markdown]
# ## Audio parameters

# %%
wav_file.channels
# Out:
# 1

# %%
wav_file.frame_rate
# Out:
# 44100

# %%
# Number of bytes per sample
wav_file.sample_width
# Out:
# 2

# %%
# The max amplitude (loudness)
wav_file.max
# Out:
# 3277

# %%
# Duration of the audio file in miliseconds
len(wav_file)
# Out:
# 9801

# %%
# Changing audio parameters
#changed_audio_segment = audio_segment.set_ATTRIBUTE_NAME(x)
print(wav_file.sample_width)
wav_file_width_1 = wav_file.set_sample_width(1)
wav_file_width_1.sample_width
# Out:
# 2
# 1
